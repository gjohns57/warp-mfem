# %% [markdown]
# ## Soft Cube Deforms from Rest Position and Maintains Non-Zero Elastic Energy

# %%
import pandas as pd
import matplotlib.pyplot as plt

log = pd.read_parquet('wierd_energy_from_nowhere.parquet')

log.loc[:, "dx"].apply(lambda x: x.reshape(-1, 3)[0, :])
# log.loc[0, "constraint"].reshape(-1, 6)
# log.loc[2, "dx"].reshape(-1, 3)
# Out:
# 0    [7.3642004e-06, 0.12499242, -2.0054169e-05, -1...
# 1    [-1.6323174e-06, 1.4993071e-05, 2.1784217e-06,...
# 2    [-1.0285294e-07, 2.0496373e-06, 4.5227353e-07,...
# 3    [6.0827006e-08, 2.2401218e-07, -2.3283064e-10,...
# Name: dx, dtype: object
